# %%
# Mount drive and cd to the Hanabi folder

from google.colab import drive
drive.mount('/content/gdrive')

# Cuda specific option

import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# Check if GPU is connected

import tensorflow as tf
tf.test.gpu_device_name()

# Install HLE

! pip install git+https://github.com/deepmind/hanabi-learning-environment.git

# Install relevant pytorch version
! pip uninstall torch
! pip install torch==1.4.0 torchvision==0.5.0
import torch
print(torch.__version__)

# Install tensorflow-gpu

! pip install absl-py gin-config tensorflow-gpu==1.15.0 numpy

# Clone the Hanabi Folder

# ! git clone https://github.com/deepmind/hanabi-learning-environment.git

# Instructions to pip install and run and python executable

# ! pip install <desired-python-library>
# ! python <executable_file.py>

# Run game_example.py

# ! python hanabi-learning-environment/examples/game_example.py
# Out:
# Mounted at /content/gdrive
# ...
#   Cloning https://github.com/deepmind/hanabi-learning-environment.git to /tmp/pip-req-build-j22fg2mq
#   Running command git clone -q https://github.com/deepmind/hanabi-learning-environment.git /tmp/pip-req-build-j22fg2mq
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for hanabi-learning-environment: filename=hanabi_learning_environment-0.0.1-cp37-cp37m-linux_x86_64.whl size=90668 sha256=421e219657bec6d1c9075b0fc1d754133dac9bbf585d70f0c72e250da771538b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-knzwuutk/wheels/70/3c/1a/3691fdbccfa4e61e3ec8c885b7498ae83931381fa453da045b
# Successfully built hanabi-learning-environment
# ...
# Found existing installation: torch 1.9.0+cu102
# Uninstalling torch-1.9.0+cu102:
#   Would remove:
#     /usr/local/bin/convert-caffe2-to-onnx
#     /usr/local/bin/convert-onnx-to-caffe2
# ...

# %%
# Go to adrqn folder

# %cd gdrive/MyDrive/Hanabi/hanabi-learning-environment/hanabi_learning_environment/agents/adrqn/
# Out:
# /content/gdrive/MyDrive/Hanabi/hanabi-learning-environment/hanabi_learning_environment/agents/adrqn

# %%
# Run self play with ADRQN agent

! python -um train --base_dir=tmp/hanabi_adrqn --gin_files='configs/hanabi_adrqn.gin'
# Out:
# /usr/bin/python3: No module named train
